# %%
import pandas as pd

# %%
s1 = pd.Series([71, 84, 73, 46, 57, 34,])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    71
# 1    84
# 2    73
# 3    46
# 4    57
# 5    34
# dtype: int64

# %%
s2 = pd.Series([71, 84, 73, 46, 57, 34], index=["rhushi","yash","aaditya","kunal","mahesh","bhavesh"])

# %%
print(s2)
# Out:
# rhushi     71
# yash       84
# aaditya    73
# kunal      46
# mahesh     57
# bhavesh    34
# dtype: int64

# %%
s2["rhushi"]
# Out:
# 71

# %%
data = {
    "name": ["rhushi","Dhanu","kunal"],
    "age": [22, 22, 20],
    "city": ["chiplun","sangmeshwar","dapoli"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name  age         city
# 0  rhushi   22      chiplun
# 1   Dhanu   22  sangmeshwar
# 2   kunal   20       dapoli

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)
